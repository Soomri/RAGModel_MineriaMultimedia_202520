# %%
import sys
import os

# Agregar la raíz del proyecto al pythonpath
ROOT_DIR = os.path.abspath("..")
if ROOT_DIR not in sys.path:
    sys.path.append(ROOT_DIR)

print(ROOT_DIR)
# Out:
# c:\Users\Sofia\RAGModel_MineriaMultimedia_202520

# %%
from src.chunking import clean_text, split_into_chunks, process_documents

# %%
BASE_INPUT = "../data/raw"
BASE_OUTPUT = "../data/preprocessed"

# %%
files = os.listdir(BASE_INPUT)
files
# Out:
# ['data_summary.json',
#  'plot_summary_breakingdawn_bookone.txt',
#  'plot_summary_breakingdawn_bookthree.txt',
#  'plot_summary_breakingdawn_booktwo.txt',
#  'plot_summary_eclipse.txt',
#  'plot_summary_midnightsun.txt',
#  'plot_summary_newmoon.txt',
#  'plot_summary_twilight.txt']

# %%
with open(os.path.join(BASE_INPUT, files[0]), 'r', encoding='utf-8') as f:
    print(f.read()[:800])
# Out:
# [
#   {
#     "id": 1,
#     "text": "Bella Swan moves from Phoenix, Arizona to the small town of Forks, Washington, to live with her father, Charlie. She soon notices the mysterious Cullen family at school, who seem pale, beautiful, and distant from everyone else."
#   },
#   {
#     "id": 2,
#     "text": "Edward Cullen, one of the Cullens, saves Bella from being crushed by a van with inhuman speed and strength. This event leads Bella to suspect that he is not an ordinary human."
#   },
#   {
#     "id": 3,
#     "text": "Edward later reveals to Bella that he is a vampire. Despite the danger, they fall deeply in love, and Bella becomes fascinated by his supernatural world."
#   },
#   {
#     "id": 4,
#     "text": "The Cullen family consists of Carlisle, Esme, Edward, Rosalie, Emmett, Alice, and Jasper. They conside

# %% [markdown]
# Se cargaron 8 documentos crudos (7 TXT, 1 JSON).

# %%
raw_text = "Ejemplo con    espacios   y saltos de línea.\n\nOtro párrafo."
print("Antes:", raw_text)
print("Después:", clean_text(raw_text))
# Out:
# Antes: Ejemplo con    espacios   y saltos de línea.
#
# Otro párrafo.
# Después: Ejemplo con espacios y saltos de línea. Otro párrafo.

# %%
from src.chunking import split_into_chunks

sample_text = r"data\raw\plot_summary_breakingdawn_bookone.txt"
chunks = split_into_chunks(sample_text, chunk_size=400, overlap=100)
len(chunks), chunks[:2]
# Out:
# (1, ['data\\raw\\plot_summary_breakingdawn_bookone.txt'])

# %%
process_documents(BASE_INPUT, BASE_OUTPUT, chunk_size=400, overlap=100)
# Out:
# 📂 Procesando documentos con chunk_size=400, overlap=100
# 📁 Carpeta destino: ../data/preprocessed\processed_400_100
#
# ✅ data_summary.json: 3 chunks creados.
# ✅ plot_summary_breakingdawn_bookone.txt: 2 chunks creados.
# ✅ plot_summary_breakingdawn_bookthree.txt: 5 chunks creados.
# ✅ plot_summary_breakingdawn_booktwo.txt: 4 chunks creados.
# ✅ plot_summary_eclipse.txt: 3 chunks creados.
# ✅ plot_summary_midnightsun.txt: 1 chunks creados.
# ✅ plot_summary_newmoon.txt: 7 chunks creados.
# ✅ plot_summary_twilight.txt: 3 chunks creados.
#
# 🎯 Proceso completado para 400-100. Archivos guardados en: ../data/preprocessed\processed_400_100

# %%
output_folder = os.path.join(BASE_OUTPUT, "processed_400_100")
os.listdir(output_folder)
# Out:
# ['data_summary_chunks.txt',
#  'plot_summary_breakingdawn_bookone_chunks.txt',
#  'plot_summary_breakingdawn_bookthree_chunks.txt',
#  'plot_summary_breakingdawn_booktwo_chunks.txt',
#  'plot_summary_eclipse_chunks.txt',
#  'plot_summary_midnightsun_chunks.txt',
#  'plot_summary_newmoon_chunks.txt',
#  'plot_summary_twilight_chunks.txt']

# %%
with open(os.path.join(output_folder, os.listdir(output_folder)[0]), 'r', encoding='utf-8') as f:
    print(f.read()[:800])
# Out:
# --- CHUNK 1 ---
# 1 Bella Swan moves from Phoenix, Arizona to the small town of Forks, Washington, to live with her father, Charlie. She soon notices the mysterious Cullen family at school, who seem pale, beautiful, and distant from everyone else. 2 Edward Cullen, one of the Cullens, saves Bella from being crushed by a van with inhuman speed and strength. This event leads Bella to suspect that he is not an ordinary human. 3 Edward later reveals to Bella that he is a vampire. Despite the danger, they fall deeply in love, and Bella becomes fascinated by his supernatural world. 4 The Cullen family consists of Carlisle, Esme, Edward, Rosalie, Emmett, Alice, and Jasper. They consider themselves 'vegetarian vampires' because they feed only on animal blood rather than humans. 5 Carlisle Cullen, the

# %% [markdown]
# Finalmente,
# * Se limpió el texto removiendo espacios y saltos innecesarios.
# * Se generaron chunks con configuración (400, 100) produciendo 28 chunks.
# * Se guardaron los chunks en:
# > /data/preprocessed/processed_400_100/
